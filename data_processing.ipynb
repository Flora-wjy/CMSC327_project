# %%
import pandas as pd

df1 = pd.read_csv("fake_job_postings.csv")
df1.drop(['department', 'telecommuting', 'has_company_logo', 'has_questions',
        'required_experience', 'required_education', 'job_id', 'function',], axis=1, inplace=True)
# df1.columns = ['title', 'location', , 'salary_range', 'company_profile', 'description', 'requirements', 'benefits',
#         'employment_type', 'industry', 'fraudulent']
df2 = pd.read_csv("fake_postings.csv")
# Out:
# Index(['title', 'location', 'salary_range', 'company_profile', 'description',
#        'requirements', 'benefits', 'employment_type', 'industry',
#        'fraudulent'],
#       dtype='object')

# %%
merged_df = pd.concat([df1, df2])
merged_df
# Out:
#                                           title            location  \
# 0                              Marketing Intern    US, NY, New York
# 1     Customer Service - Cloud Video Production      NZ, , Auckland
# 2       Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3             Account Executive - Washington DC  US, DC, Washington
# 4                           Bill Review Manager  US, FL, Fort Worth
# ...                                         ...                 ...
# 9995                        Designer, furniture           Paulabury
# 9996             Therapist, speech and language      Moraleschester
# 9997                          Therapist, sports      Christinemouth
# 9998                Clinical research associate   Lake Meredithberg
# 9999                        Hospital pharmacist        Samanthaland
#
#         salary_range                                    company_profile  \
# 0                NaN  We're Food52, and we've created a groundbreaki...
# ...
